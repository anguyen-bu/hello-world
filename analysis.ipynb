# %%
import pandas as pd

# %%
df = pd.read_csv("ncr_ride_bookings.csv")

# %%
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df[["Booking Value", "Ride Distance"]].iloc[:100].plot(kind="scatter", x="Booking Value", y= "Ride Distance")
# Out:
# <Axes: xlabel='Booking Value', ylabel='Ride Distance'>

# %%
df.groupby("Payment Method")["Date"].count().plot(kind="bar")
# Out:
# <Axes: xlabel='Payment Method'>

# %%
import sklearn 
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(df_no_na[["Avg CTAT"]], df["Ride Distance"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 model = LinearRegression()
# ----> 2 model.fit(df_no_na[["Avg CTAT"]], df["Ride Distance"])
#
# File ~/.local/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/linear_model/_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
# ...

# %%
df_no_na = df[["Avg CTAT", "Ride Distance"]].dropna()
# Out:
#         Avg CTAT  Ride Distance
# 1           14.0           5.73
# 2           25.8          13.58
# 3           28.5          34.02
# 4           19.6          48.21
# 5           18.1           4.85
# ...          ...            ...
# 149995      44.4          40.08
# 149996      30.8          21.31
# 149997      23.4          15.93
# 149998      39.6          45.54
# 149999      33.7          21.19
#
# [102000 rows x 2 columns]

# %%
model = LinearRegression()
model.fit(df_no_na[["Avg CTAT"]], df_no_na["Ride Distance"])
# Out:
# LinearRegression()
